# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\heart-disease-uci\heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data['age_group']=0
data.loc[data['age']<30, 'age_group']='young'

# %%
data.loc[data['age']>60, 'age_group']='old'

# %%
data.loc[data['age'].between(30,61), 'age_group']='adult'

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target age_group
# 0   0     1       1       old
# 1   0     2       1     adult
# 2   0     2       1     adult
# 3   0     2       1     adult
# 4   0     2       1     adult

# %%
data[data['age']<=30]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72   29    1   1       130   204    0        0      202      0      0.0
#
#     slope  ca  thal  target age_group
# 72      2   0     2       1     young

# %%
data.age_group.value_counts()
# Out:
# adult    231
# old       71
# young      1
# Name: age_group, dtype: int64

# %%
data.groupby('age_group').max()
# Out:
#            age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# age_group
# adult       61    1   3       200   409    1        2      195      1
# old         77    1   3       180   564    1        2      179      1
# young       29    1   1       130   204    0        0      202      0
#
#            oldpeak  slope  ca  thal  target
# age_group
# adult          5.6      2   4     3       1
# old            6.2      2   3     3       1
# young          0.0      2   0     2       1

# %%
data.groupby('age_group').min()
# Out:
#            age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# age_group
# adult       34    0   0        94   126    0        0       88      0
# old         62    0   0       100   149    0        0       71      0
# young       29    1   1       130   204    0        0      202      0
#
#            oldpeak  slope  ca  thal  target
# age_group
# adult          0.0      0   0     0       0
# old            0.0      0   0     1       0
# young          0.0      2   0     2       1

# %%
data.groupby('age').max()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 29     1   1       130   204    0        0      202      0      0.0      2
# 34     1   3       118   210    0        1      192      0      0.7      2
# 35     1   1       138   282    0        1      182      1      1.6      2
# 37     1   2       130   250    0        1      187      0      3.5      2
# 38     1   3       138   231    0        1      182      1      3.8      2
# 39     1   2       140   321    0        1      182      0      1.2      2
# 40     1   3       152   223    0        1      181      1      2.0      2
# 41     1   2       135   306    0        1      182      1      2.0      2
# 42     1   3       148   315    1        1      194      1      1.8      2
# 43     1   2       150   341    1        1      181      1      3.0      2
# 44     1   2       140   290    0        1      188      1      2.8      2
# ...

# %%
data.groupby('age').agg({'target':'sum'})  # no of heart diesase patients in each age group

# df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})
# Out:
#      target
# age
# 29        1
# 34        2
# 35        2
# 37        2
# 38        2
# 39        3
# 40        1
# 41        9
# 42        7
# 43        5
# 44        8
# 45        6
# 46        4
# 47        3
# 48        4
# 49        3
# 50        4
# 51        9
# 52        9
# 53        6
# 54       10
# 55        3
# 56        5
# 57        7
# 58        7
# 59        5
# 60        3
# 61        1
# 62        4
# 63        3
# 64        6
# 65        4
# 66        4
# 67        3
# 68        2
# 69        2
# 70        1
# 71        3
# 74        1
# 76        1
# 77        0
